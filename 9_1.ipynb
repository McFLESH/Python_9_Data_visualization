# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_9_Data_visualization/blob/main/9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Постройте столбчатую диаграмму

import matplotlib.pyplot as plt
def data_bar(x, y):
    return plt.bar(x, y)
