# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_9_Data_visualization/blob/main/9_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Постройте два линейный графика на одной плоскости

import matplotlib.pyplot as plt
def two_plots(y1, y2):
    fig, ax = plt.subplots()
    ax.plot(y1, label='Dataset 1')
    ax.plot(y2, label='Dataset 2')
    ax.set_xlabel('Индекс')
    ax.set_ylabel('Значение')
    ax.set_title('Сравнение двух датасетов')
    ax.legend()
    return ax
